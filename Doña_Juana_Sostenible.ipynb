# %% [markdown]
# <a href="https://colab.research.google.com/github/993Andres/Cartilla---Sostenibilidad/blob/main/Do%C3%B1a_Juana_Sostenible.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Doña Juana Sostenible - SIG</title>
#
# <script src="https://cdn.tailwindcss.com"></script>
# <link href="https://fonts.googleapis.com/css2?family=Quicksand:wght@400;600;700&display=swap" rel="stylesheet">
# <script src="https://unpkg.com/lucide@latest"></script>
#
# <style>
# body { font-family: 'Quicksand', sans-serif; background-color: #f0f4f8; }
# .rounded-xl-custom { border-radius: 2rem; }
# .rounded-header { border-bottom-left-radius: 4rem; border-bottom-right-radius: 4rem; }
# .boletin { display: none; }
# .boletin.active { display: block; }
# </style>
# </head>
#
# <body class="pb-20">
#
# <!-- HEADER -->
# <header class="bg-gradient-to-br from-[#005357] to-[#00a5ba] text-white pt-12 pb-24 px-6 rounded-header text-center">
#     <h1 class="text-3xl font-extrabold uppercase">Doña Juana Sostenible</h1>
#     <p class="text-[#dbf09b] font-semibold">Sistema Integrado de Gestión - Cultura HSEQ</p>
# </header>
#
# <main class="max-w-md mx-auto px-6 -mt-12 space-y-6" id="bulletinContent">
#
# <!-- INTRO -->
# <section class="bg-white p-6 rounded-xl-custom shadow">
#     <h2 class="font-bold text-[#005357] text-lg mb-2">¿Qué es Doña Juana Sostenible?</h2>
#     <p class="text-slate-600 text-sm">
#         Estrategia de fortalecimiento de la cultura organizacional HSEQ que busca la apropiación de prácticas ambientales, de seguridad y calidad en CGR Doña Juana.
#     </p>
# </section>
#
# <!-- JUNIO (Now an independent section) -->
# <section id="junio" class="bg-[#005357] text-white p-6 rounded-xl-custom shadow">
# <h2 class="font-bold mb-3">🌳 Junio - Campaña de Expectativa</h2>
#
# <p class="text-sm text-[#dbf09b] mb-4">
# Algo grande se está preparando...
# </p>
#
# <h3 class="font-bold text-lg mb-2">🚀 Rally Doña Juana Circular</h3>
#
# <p class="text-sm mb-3">
# Muy pronto pondremos a prueba tu compromiso con la economía circular.
# Un reto donde cada acción cuenta para transformar residuos en oportunidades.
# </p>
#
# <ul class="text-sm space-y-2">
# <li>♻️ Recuperación responsable de materiales</li>
# <li>💚 Construcción de botellas de amor</li>
# <li>🤝 Trabajo en equipo</li>
# </ul>
#
# <p class="text-xs mt-4 text-[#dbf09b]">
# Sin generar residuos adicionales. Solo aprovechando lo que ya existe.
# </p>
#
# <p class="mt-4 font-bold text-center">
# 🔔 Prepárate | Julio - Septiembre 2026
# </p>
# </section>
#
# <!-- MENU BOLETINES -->
# <section class="bg-white p-6 rounded-xl-custom shadow">
#     <h2 class="font-bold text-[#005357] mb-4 flex items-center gap-2">
#         <i data-lucide="book-open"></i> Boletines
#     </h2>
#
#     <div class="grid grid-cols-2 gap-3 text-sm">
#         <button onclick="showBoletin('marzo')" class="btn">🌱 Marzo</button>
#         <button onclick="showBoletin('abril')" class="btn">♻️ Abril</button>
#         <button onclick="showBoletin('mayo')" class="btn">🌍 Mayo</button>
#     </div>
# </section>
#
# <!-- MARZO -->
# <section id="marzo" class="boletin bg-white p-6 rounded-xl-custom shadow active">
# <h2 class="font-bold text-[#005357] mb-3">🌱 Marzo - Educación ambiental</h2>
#
# <p class="text-sm text-slate-600 mb-3">
# Ciclo de capacitaciones interactivas con enfoque práctico:
# </p>
#
# <ul class="text-sm text-slate-700 space-y-1">
# <li>💧 Día del Agua – 22 marzo</li>
# <li>🌎 Hora del planeta – 23 y 26 marzo</li>
# <li>♻️ Cero residuos – 30 marzo</li>
# </ul>
#
# <p class="text-xs mt-3">Aprecia el valor de los recursos naturales.</p>
# </section>
#
#
# <!-- ABRIL -->
# <section id="abril" class="boletin bg-white p-6 rounded-xl-custom shadow">
# <h2 class="font-bold text-[#005357] mb-3">♻️ Abril - Economía Circular</h2>
#
# <ul class="text-sm text-slate-700 space-y-2">
# <li>🔙 21 Abr – RETORNA (posconsumo)</li>
# <li>🌎 22 Abr – Reciclatón </li>
# <li>📚 23 Abr – Idioma Circular</li>
# </ul>
#
# <p class="text-xs mt-3">Una semana para aprender, cuidar y transformar.</p>
# </section>
#
# <!-- MAYO -->
# <section id="mayo" class="boletin bg-white p-6 rounded-xl-custom shadow">
# <h2 class="font-bold text-[#005357] mb-3">🌍 Mayo - Experiencias ambientales</h2>
#
# <ul class="text-sm text-slate-700 space-y-2">
# <li>🧹 19 May – Organización del puesto</li>
# <li>🐝 20 May – Apicultura</li>
# <li>🌄 22 May – Caminata ecológica</li>
# </ul>
#
# <p class="text-xs mt-3">
# Generamos valor ambiental desde nuestra operación.
# </p>
# </section>
#
#
# <!-- PARTICIPACIÓN -->
# <section class="bg-white p-6 rounded-xl-custom shadow text-center">
# <h2 class="font-bold text-[#005357] mb-2">Mi compromiso</h2>
#
# <p class="text-sm text-slate-500 mb-4">
# Registra tu participación en las actividades
# </p>
#
# <button onclick="openForm()" class="bg-[#00a5ba] text-white px-6 py-4 rounded-full font-bold">
# Participar
# </button>
# </section>
#
# </main>
#
# <script>
# lucide.createIcons();
#
# function showBoletin(id){
#     document.querySelectorAll(".boletin").forEach(b => b.classList.remove("active"));
#     document.getElementById(id).classList.add("active");
# }
#
# function openForm(){
#     window.open("https://forms.cloud.microsoft/r/GWXj3qM1Nx");
# }
# </script>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Doña Juana Sostenible - SIG</title>
#
# <script src="https://cdn.tailwindcss.com"></script>
# <link href="https://fonts.googleapis.com/css2?family=Quicksand:wght@400;600;700&display=swap" rel="stylesheet">
# <script src="https://unpkg.com/lucide@latest"></script>
#
# <style>
# body { font-family: 'Quicksand', sans-serif; background-color: #f0f4f8; }
# .rounded-xl-custom { border-radius: 2rem; }
# .rounded-header { border-bottom-left-radius: 4rem; border-bottom-right-radius: 4rem; }
# .boletin { display: none; }
# .boletin.active { display: block; }
# </style>
# </head>
#
# <body class="pb-20">
#
# <!-- HEADER -->
# <header class="bg-gradient-to-br from-[#005357] to-[#00a5ba] text-white pt-12 pb-24 px-6 rounded-header text-center">
#     <h1 class="text-3xl font-extrabold uppercase">Doña Juana Sostenible</h1>
# ...
